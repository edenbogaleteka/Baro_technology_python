# %% [markdown]
# ***standard_calculator**

# %%
def calculator(): 
    print('standard calculator')
    try:
        while True :
            # begining of operator module
            operator=input('enter the operator [+,-,*,**,/and exit]').strip().lower()
            if operator == 'exit':
                print('exiting the calculator')
                break
            list_op=['+','-','*','/','**']
            if operator not in list_op:
                print('please enter the correct operator')
                continue
                # end of operator module

               # begining of number module
            numbers=[]
            while  True:
                number=input('please enter a number or = sign in order to  calculate').strip()

                if number.lower()=='=':
                    if len(numbers)>2:
                        print('enter atleast 2 numbers')
                        continue
                    break
                try:
                        num=float(number)
                        numbers.append(num)
                except ValueError:
                    print('please enter number only!')
                    continue
                # end of number module

                # begining of arthimetic operation
            
            if operator == '+':
                result =numbers[0]
                for number in numbers[1:]:
                    result=result+number
                print('+'.join(map(str,numbers)) + f" = {result}")
            elif operator == '-':
                result =numbers[0]
                for number in numbers[1:]:
                    result=result-number
                print('-'.join(map(str,numbers)) + f" = {result}")
            elif operator == '*':
                result =numbers[0]
                for number in numbers[1:]:
                    result=result*number
                print('*'.join(map(str,numbers)) + f" = {result}")
            elif operator == '/':
                result =numbers[0]
                try:
                    for number in numbers[1:]:
                        if number ==0:
                            raise ZeroDivisionError()
                    result=result/number
                    print('/'.join(map(str,numbers)) + f" = {result}")
                except ZeroDivisionError:
                    print('denominator can not be zero' )
            elif operator == '**':
                result =numbers[0]
                for number in numbers[1:]:
                    result=result**number
                print('**'.join(map(str,numbers)) + f" = {result}")
    except Exception as e:
        print(f'invalid operations!{e} ')
    print('developed by: EDEN')
    
calculator()
# Out:
# standard calculator
# enter atleast 2 numbers
# enter atleast 2 numbers
# please enter number only!
# please enter number only!
# enter atleast 2 numbers
# enter atleast 2 numbers
# enter atleast 2 numbers
# please enter number only!
# please enter number only!
# please enter number only!
# enter atleast 2 numbers
# enter atleast 2 numbers
# enter atleast 2 numbers
# enter atleast 2 numbers
# enter atleast 2 numbers
# enter atleast 2 numbers
# enter atleast 2 numbers
# enter atleast 2 numbers
# enter atleast 2 numbers
# enter atleast 2 numbers
# enter atleast 2 numbers
# enter atleast 2 numbers
# enter atleast 2 numbers
# enter atleast 2 numbers
# please enter number only!
# please enter number only!
# please enter number only!
# please enter number only!
# please enter number only!
# enter atleast 2 numbers
# enter atleast 2 numbers
# please enter number only!
# please enter number only!
# please enter number only!
# please enter number only!
# please enter number only!
# please enter number only!
# please enter number only!
# please enter number only!
# please enter number only!
# please enter number only!
# please enter number only!
# please enter number only!
# please enter number only!
# please enter number only!
# please enter number only!
# please enter number only!
# please enter number only!
# please enter number only!
# please enter number only!
# please enter number only!
# please enter number only!
# please enter number only!
# please enter number only!
# enter atleast 2 numbers
# please enter number only!
# please enter number only!
# enter atleast 2 numbers
# enter atleast 2 numbers
# enter atleast 2 numbers
# enter atleast 2 numbers
# please enter number only!
# please enter number only!
# please enter number only!
# please enter number only!
# please enter number only!
# enter atleast 2 numbers
# enter atleast 2 numbers
# please enter number only!
# enter atleast 2 numbers
# please enter number only!
# enter atleast 2 numbers
# please enter number only!
# please enter number only!
# enter atleast 2 numbers
# enter atleast 2 numbers
# enter atleast 2 numbers
# please enter number only!
# please enter number only!
# please enter number only!
# please enter number only!
# please enter number only!
# enter atleast 2 numbers
# please enter number only!
# please enter number only!
# enter atleast 2 numbers
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 71
#      68         print(f'invalid operations!{e} ')
#      69     print('developed by: EDEN')
# ---> 71 calculator()
#
# Cell In[3], line 19, in calculator()
#      17 numbers=[]
#      18 while  True:
# ---> 19     number=input('please enter a number or = sign in order to  calculate').strip()
#      21     if number.lower()=='=':
#      22         if len(numbers)>2:
#
# File ~\AppData\Roaming\Python\Python313\site-packages\ipykernel\kernelbase.py:1260, in Kernel.raw_input(self, prompt)
#    1258     msg = "raw_input was called, but this frontend does not support input requests."
#    1259     raise StdinNotImplementedError(msg)
# -> 1260 return self._input_request(
#    1261     str(prompt),
#    1262     self._parent_ident["shell"],
#    1263     self.get_parent("shell"),
#    1264     password=False,
#    1265 )
#
# File ~\AppData\Roaming\Python\Python313\site-packages\ipykernel\kernelbase.py:1305, in Kernel._input_request(self, prompt, ident, parent, password)
#    1302 except KeyboardInterrupt:
#    1303     # re-raise KeyboardInterrupt, to truncate traceback
#    1304     msg = "Interrupted by user"
# -> 1305     raise KeyboardInterrupt(msg) from None
#    1306 except Exception:
#    1307     self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user
